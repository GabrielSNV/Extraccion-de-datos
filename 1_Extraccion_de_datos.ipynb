# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrielSNV/Extraccion-de-datos/blob/main/1_Extraccion_de_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-aa74cd56-0190-4a68-b175-dc6e5e501aef" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-aa74cd56-0190-4a68-b175-dc6e5e501aef">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv("CountryTable.csv")

# %%
df.head(5)
# Out:
#   code         name      continent                     region  surface_area  \
# 0  ABW        Aruba  North America                  Caribbean         193.0
# 1  AFG  Afghanistan           Asia  Southern and Central Asia      652090.0
# 2  AGO       Angola         Africa             Central Africa     1246700.0
# 3  AIA     Anguilla  North America                  Caribbean          96.0
# 4  ALB      Albania         Europe            Southern Europe       28748.0
#
#    independence_year  population  life_expectancy     gnp  gnp_old  \
# 0                NaN      103000             78.4   828.0    793.0
# 1             1919.0    22720000             45.9  5976.0      NaN
# 2             1975.0    12878000             38.3  6648.0   7984.0
# 3                NaN        8000             76.1    63.2      NaN
# 4             1912.0     3401200             71.6  3205.0   2500.0
#
#               local_name                               government_form  \
# ...

# %%
filtro1=df[df["continent"]=="North America"]
filtro1
# Out:
#     code                              name      continent           region  \
# 0    ABW                             Aruba  North America        Caribbean
# 3    AIA                          Anguilla  North America        Caribbean
# 6    ANT              Netherlands Antilles  North America        Caribbean
# 13   ATG               Antigua and Barbuda  North America        Caribbean
# 24   BHS                           Bahamas  North America        Caribbean
# 27   BLZ                            Belize  North America  Central America
# 28   BMu                           Bermuda  North America    North America
# 31   BRB                          Barbados  North America        Caribbean
# 37   CAN                            Canada  North America    North America
# 50   CRI                        Costa Rica  North America  Central America
# 51   CuB                              Cuba  North America        Caribbean
# ...

# %% [markdown]
# Se filtro en la columna de continente los datos con la variable Norte America

# %%
filtro2=df.iloc[45:50, : ]
filtro2
# Out:
#    code          name      continent          region  surface_area  \
# 45  COG         Congo         Africa  Central Africa      342000.0
# 46  COK  Cook Islands        Oceania       Polynesia         236.0
# 47  COL      Colombia  South America   South America     1138914.0
# 48  COM       Comoros         Africa  Eastern Africa        1862.0
# 49  CPV    Cape Verde         Africa  Western Africa        4033.0
#
#     independence_year  population  life_expectancy       gnp   gnp_old  \
# 45             1960.0     2943000             47.4    2108.0    2287.0
# 46                NaN       20000             71.1     100.0       NaN
# 47             1810.0    42321000             70.3  102896.0  105116.0
# 48             1975.0      578000             60.0    4401.0    4361.0
# 49             1975.0      428000             68.9     435.0     420.0
#
#           local_name                           government_form  \
# 45             Congo                                  Republic
# ...

# %% [markdown]
# se filtraron 5 filas desde la 45 a la 49

# %%
filtro3=df.iloc[ : , [1,2,5,7]]
filtro3
# Out:
#              name      continent  independence_year  life_expectancy
# 0           Aruba  North America                NaN             78.4
# 1     Afghanistan           Asia             1919.0             45.9
# 2          Angola         Africa             1975.0             38.3
# 3        Anguilla  North America                NaN             76.1
# 4         Albania         Europe             1912.0             71.6
# ..            ...            ...                ...              ...
# 234         Yemen           Asia             1918.0             59.8
# 235    Yugoslavia         Europe             1918.0             72.4
# 236  South Africa         Africa             1910.0             51.1
# 237        Zambia         Africa             1964.0             37.2
# 238      Zimbabwe         Africa             1980.0             37.8
#
# [239 rows x 4 columns]

# %% [markdown]
# se filtraron de todas las filas las columnas 1, 2, 5 y 7

# %%
df=pd.read_csv("CountryTable.csv", index_col=1)
df
# Out:
#              code      continent                     region  surface_area  \
# name
# Aruba         ABW  North America                  Caribbean         193.0
# Afghanistan   AFG           Asia  Southern and Central Asia      652090.0
# Angola        AGO         Africa             Central Africa     1246700.0
# Anguilla      AIA  North America                  Caribbean          96.0
# Albania       ALB         Europe            Southern Europe       28748.0
# ...           ...            ...                        ...           ...
# Yemen         YEM           Asia                Middle East      527968.0
# Yugoslavia    YuG         Europe            Southern Europe      102173.0
# South Africa  ZAF         Africa            Southern Africa     1221037.0
# Zambia        ZMB         Africa             Eastern Africa      752618.0
# Zimbabwe      ZWE         Africa             Eastern Africa      390757.0
#
#               independence_year  population  life_expectancy       gnp  \
# ...

# %%
filtro4=df.loc[["Mexico","united States"],["life_expectancy"]]
filtro4
# Out:
#                life_expectancy
# name
# Mexico                    71.5
# united States             77.1

# %% [markdown]
# Se filtró la expectativa de vida de los paises México y Estados Unidos

# %%
filtro5=df.head(10)
filtro5
# Out:
#                      code      continent                     region  \
# name
# Aruba                 ABW  North America                  Caribbean
# Afghanistan           AFG           Asia  Southern and Central Asia
# Angola                AGO         Africa             Central Africa
# Anguilla              AIA  North America                  Caribbean
# Albania               ALB         Europe            Southern Europe
# Andorra               AND         Europe            Southern Europe
# Netherlands Antilles  ANT  North America                  Caribbean
# united Arab Emirates  ARE           Asia                Middle East
# Argentina             ARG  South America              South America
# Armenia               ARM           Asia                Middle East
#
#                       surface_area  independence_year  population  \
# name
# Aruba                        193.0                NaN      103000
# Afghanistan               652090.0             1919.0    22720000
# ...

# %% [markdown]
# Se filtraron las primeras diez filas de los datos

# %%
filtro6=df[df["life_expectancy"]>80]
filtro6
# Out:
#            code continent           region  surface_area  independence_year  \
# name
# Andorra     AND    Europe  Southern Europe         468.0             1278.0
# Japan       JPN      Asia     Eastern Asia      377829.0             -660.0
# Macao       MAC      Asia     Eastern Asia          18.0                NaN
# Singapore   SGP      Asia   Southeast Asia         618.0             1965.0
# San Marino  SMR    Europe  Southern Europe          61.0              885.0
#
#             population  life_expectancy        gnp    gnp_old  \
# name
# Andorra          78000             83.5     1630.0        NaN
# Japan        126714000             80.7  3787042.0  4192638.0
# Macao           473000             81.6     5749.0     5940.0
# Singapore      3567000             80.1    86503.0    96318.0
# San Marino       27000             81.1      510.0        NaN
#
#                                        local_name  \
# name
# Andorra                                   Andorra
# ...

# %% [markdown]
# Se filtraron los datos que tuvieran una expectativa de vida mayor a 80

# %%
filtro7=df[(df["continent"]=="Asia") & (df["life_expectancy"] >80)]
filtro7
# Out:
#           code continent          region  surface_area  independence_year  \
# name
# Japan      JPN      Asia    Eastern Asia      377829.0             -660.0
# Macao      MAC      Asia    Eastern Asia          18.0                NaN
# Singapore  SGP      Asia  Southeast Asia         618.0             1965.0
#
#            population  life_expectancy        gnp    gnp_old  \
# name
# Japan       126714000             80.7  3787042.0  4192638.0
# Macao          473000             81.6     5749.0     5940.0
# Singapore     3567000             80.1    86503.0    96318.0
#
#                                       local_name  \
# name
# Japan                               Nihon/Nippon
# Macao                                Macau/Aomen
# Singapore  Singapore/Singapura/Xinjiapo/Singapur
#
#                                   government_form         head_of_state  \
# name
# Japan                     Constitutional Monarchy               Akihito
# ...

# %% [markdown]
# Se filtraron los datos pertencecientes a Asia y con una expectativa de vida mayor a 80

# %%
filtro8=df[(df["population"]>200000000) | (df["independence_year"]>1990)]
filtro8
# Out:
#     code                    name      continent                     region  \
# 9    ARM                 Armenia           Asia                Middle East
# 16   AZE              Azerbaijan           Asia                Middle East
# 25   BIH  Bosnia and Herzegovina         Europe            Southern Europe
# 26   BLR                 Belarus         Europe             Eastern Europe
# 41   CHN                   China           Asia               Eastern Asia
# 55   CZE          Czech Republic         Europe             Eastern Europe
# 64   ERI                 Eritrea         Africa             Eastern Africa
# 67   EST                 Estonia         Europe           Baltic Countries
# 77   GEO                 Georgia           Asia                Middle East
# 95   HRV                 Croatia         Europe            Southern Europe
# 98   IDN               Indonesia           Asia             Southeast Asia
# ...

# %% [markdown]
# Se filtraron los datos con una poblaciín mayor a 200 millones o con un año de independencia mayor a 1990

# %%
filtro9=df[(df["population"]>200000000) & ~ (df["independence_year"]>1900)]
filtro9
# Out:
#               code      continent         region  surface_area  \
# name
# China          CHN           Asia   Eastern Asia     9572900.0
# united States  uSA  North America  North America     9363520.0
#
#                independence_year  population  life_expectancy        gnp  \
# name
# China                    -1523.0  1277558000             71.4   982268.0
# united States             1776.0   278357000             77.1  8510700.0
#
#                  gnp_old     local_name   government_form   head_of_state  \
# name
# China           917719.0       Zhongquo  People'sRepublic     Jiang Zemin
# united States  8110900.0  united States  Federal Republic  George W. Bush
#
#                capital code2
# name
# China           1891.0    CN
# united States   3813.0    uS

# %% [markdown]
# Se filtraron los datos con una población mayor a 200 millones y que su año de independencia no sea mayor a 1900

# %%
filtro1.to_csv("Entregable1.1.csv")
filtro2.to_csv("Entregable1.2.csv")
filtro3.to_csv("Entregable1.3.csv")
filtro4.to_csv("Entregable1.4.csv")
filtro5.to_csv("Entregable1.5.csv")
filtro6.to_csv("Entregable1.6.csv")
filtro7.to_csv("Entregable1.7.csv")
filtro8.to_csv("Entregable1.8.csv")
filtro9.to_csv("Entregable1.9.csv")

# %%
from google.colab import files


files.download("Entregable1.1.csv")
files.download("Entregable1.2.csv")
files.download("Entregable1.3.csv")
files.download("Entregable1.4.csv")
files.download("Entregable1.5.csv")
files.download("Entregable1.6.csv")
files.download("Entregable1.7.csv")
files.download("Entregable1.8.csv")
files.download("Entregable1.9.csv")
